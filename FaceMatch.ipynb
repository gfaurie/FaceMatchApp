# %%
#pip intall deepface
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\VR' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
#Not matching
img1_path = "./img/000001.jpg"
img2_path = "./img/000002.jpg"

#Matching
img3_path = "./img/000404.jpg"
img4_path = "./img/003415.jpg"

# %%
img1 = cv2.imread(img1_path)
img2 = cv2.imread(img2_path)
img3 = cv2.imread(img3_path)
img4 = cv2.imread(img4_path)

# %%
plt.imshow(img1[:, :, ::-1])
plt.show()
plt.imshow(img2[:, :, ::-1])
plt.show()
plt.imshow(img3[:, :, ::-1])
plt.show()
plt.imshow(img4[:, :, ::-1])
plt.show()

# %%
#Not matching
result_img1_img2 = DeepFace.verify(img1_path, img2_path)
result_img1_img2
# Out:
# Using VGG-Face model backend and cosine distance.
# {'verified': False,
#  'distance': 0.6281275749206543,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
#Matching
result_img1_img3 = DeepFace.verify(img1_path, img3_path)
result_img1_img3
# Out:
# Using VGG-Face model backend and cosine distance.
# {'verified': True,
#  'distance': 0.32775235176086426,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
#Matching
result_img1_img4 = DeepFace.verify(img1_path, img4_path)
result_img1_img4
# Out:
# Using VGG-Face model backend and cosine distance.
# {'verified': True,
#  'distance': 0.29440879821777344,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
#Matching
result_img3_img4 = DeepFace.verify(img3_path, img4_path)
result_img3_img4
# Out:
# Using VGG-Face model backend and cosine distance.
# {'verified': True,
#  'distance': 0.2010696530342102,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
#Not matching
result_img2_img4 = DeepFace.verify(img2_path, img4_path)
result_img2_img4
# Out:
# Using VGG-Face model backend and cosine distance.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002302375B940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {'verified': False,
#  'distance': 0.6284887492656708,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
DeepFace.analyze(img1_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002302361FAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Action: age:  25%|██▌       | 1/4 [00:00<00:00,  4.34it/s]
# ...

# %%
DeepFace.analyze(img2_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:tensorflow:10 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002310C439D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Action: age:  25%|██▌       | 1/4 [00:00<00:00,  5.89it/s]
# ...
